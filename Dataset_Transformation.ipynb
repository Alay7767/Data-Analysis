# %%
# Part 1

import pandas as AP
ap = AP.read_csv("C:\\Assignments\\511\\adult.data", header = None)
ap
# Out:
#        0                  1       2            3   4                    5   \
# 0      39          State-gov   77516    Bachelors  13        Never-married
# 1      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 2      38            Private  215646      HS-grad   9             Divorced
# 3      53            Private  234721         11th   7   Married-civ-spouse
# 4      28            Private  338409    Bachelors  13   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32556  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32557  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32558  58            Private  151910      HS-grad   9              Widowed
# 32559  22            Private  201490      HS-grad   9        Never-married
# 32560  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
# ...

# %%
# Before removing ?

ap.shape
# Out:
# (32561, 15)

# %%
ap = ap[ ~ ap.isin([" ?"]).any(axis=1)]

# %%
# After removing ?

ap.shape
# Out:
# (30162, 15)

# %%
# Ordinal

ap[3].unique().tolist()
# Out:
# [' Bachelors',
#  ' HS-grad',
#  ' 11th',
#  ' Masters',
#  ' 9th',
#  ' Some-college',
#  ' Assoc-acdm',
#  ' 7th-8th',
#  ' Doctorate',
#  ' Assoc-voc',
#  ' Prof-school',
#  ' 5th-6th',
#  ' 10th',
#  ' Preschool',
#  ' 12th',
#  ' 1st-4th']

# %%
edu_map = {
 ' Doctorate':14,
 ' Prof-school':13,
 ' Masters':12,
 ' Bachelors' :11,
 ' Assoc-acdm' :10,
 ' Assoc-voc' :10,
 ' some-college' :9,
 ' HS-grad':8,
 ' 12th':7,
 ' 11th': 6,
 ' 10th': 5,
 ' 9th':4,
 ' 7th-8th': 3,
 ' 5th-6th': 2,
 ' 1st-4th' :1,
 ' Preschool' :0
}
ap["Education"] = ap[3].map(edu_map)

# %%
ap
# Out:
#         0                  1       2            3   4                    5  \
# 0      39          State-gov   77516    Bachelors  13        Never-married
# 1      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 2      38            Private  215646      HS-grad   9             Divorced
# 3      53            Private  234721         11th   7   Married-civ-spouse
# 4      28            Private  338409    Bachelors  13   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32556  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32557  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32558  58            Private  151910      HS-grad   9              Widowed
# 32559  22            Private  201490      HS-grad   9        Never-married
# 32560  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
# ...

# %%
ap[14].unique().tolist()
# Out:
# [' <=50K', ' >50K']

# %%
edu_map2 = {' <=50K' : 0, ' >50K' : 1}
ap["Salary"] = ap[14].map(edu_map2)
ap
# Out:
#         0                  1       2            3   4                    5  \
# 0      39          State-gov   77516    Bachelors  13        Never-married
# 1      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 2      38            Private  215646      HS-grad   9             Divorced
# 3      53            Private  234721         11th   7   Married-civ-spouse
# 4      28            Private  338409    Bachelors  13   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32556  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32557  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32558  58            Private  151910      HS-grad   9              Widowed
# 32559  22            Private  201490      HS-grad   9        Never-married
# 32560  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
# ...

# %%
# Categorical

cC = [1,5,6,7,8,9,13]
for i in cC:
 ap = AP.concat([ap, AP.get_dummies(ap[i])],axis=1)

# %%
ap
# Out:
#         0                  1       2            3   4                    5  \
# 0      39          State-gov   77516    Bachelors  13        Never-married
# 1      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 2      38            Private  215646      HS-grad   9             Divorced
# 3      53            Private  234721         11th   7   Married-civ-spouse
# 4      28            Private  338409    Bachelors  13   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32556  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32557  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32558  58            Private  151910      HS-grad   9              Widowed
# 32559  22            Private  201490      HS-grad   9        Never-married
# 32560  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
# ...

# %%
# Part 2

ap1 = AP.read_csv("C:\\Assignments\\511\\googleplaystore.csv")
ap1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# Before removing ?

ap1.shape
# Out:
# (10841, 13)

# %%
ap1 = ap1.dropna()

# %%
# After removing ?

ap1.shape
# Out:
# (9360, 13)

# %%
# No Use

ap1 = ap1.drop(columns=["App"])
ap1
# Out:
#                   Category  Rating Reviews                Size     Installs  \
# 0           ART_AND_DESIGN     4.1     159                 19M      10,000+
# 1           ART_AND_DESIGN     3.9     967                 14M     500,000+
# 2           ART_AND_DESIGN     4.7   87510                8.7M   5,000,000+
# 3           ART_AND_DESIGN     4.5  215644                 25M  50,000,000+
# 4           ART_AND_DESIGN     4.3     967                2.8M     100,000+
# ...                    ...     ...     ...                 ...          ...
# 10834               FAMILY     4.0       7                2.6M         500+
# 10836               FAMILY     4.5      38                 53M       5,000+
# 10837               FAMILY     5.0       4                3.6M         100+
# 10839  BOOKS_AND_REFERENCE     4.5     114  Varies with device       1,000+
# 10840            LIFESTYLE     4.5  398307                 19M  10,000,000+
#
# ...

# %%
ap1["Size"] = ap1["Size"].str.replace("M", "", regex=False)
ap1
# Out:
#                   Category  Rating Reviews                Size     Installs  \
# 0           ART_AND_DESIGN     4.1     159                  19      10,000+
# 1           ART_AND_DESIGN     3.9     967                  14     500,000+
# 2           ART_AND_DESIGN     4.7   87510                 8.7   5,000,000+
# 3           ART_AND_DESIGN     4.5  215644                  25  50,000,000+
# 4           ART_AND_DESIGN     4.3     967                 2.8     100,000+
# ...                    ...     ...     ...                 ...          ...
# 10834               FAMILY     4.0       7                 2.6         500+
# 10836               FAMILY     4.5      38                  53       5,000+
# 10837               FAMILY     5.0       4                 3.6         100+
# 10839  BOOKS_AND_REFERENCE     4.5     114  Varies with device       1,000+
# 10840            LIFESTYLE     4.5  398307                  19  10,000,000+
#
# ...

# %%
ap1["Installs"] = ap1["Installs"].str.replace("+", "", regex=False).str.replace(",", "", regex=False)
ap1
# Out:
#                   Category  Rating Reviews                Size  Installs  \
# 0           ART_AND_DESIGN     4.1     159                  19     10000
# 1           ART_AND_DESIGN     3.9     967                  14    500000
# 2           ART_AND_DESIGN     4.7   87510                 8.7   5000000
# 3           ART_AND_DESIGN     4.5  215644                  25  50000000
# 4           ART_AND_DESIGN     4.3     967                 2.8    100000
# ...                    ...     ...     ...                 ...       ...
# 10834               FAMILY     4.0       7                 2.6       500
# 10836               FAMILY     4.5      38                  53      5000
# 10837               FAMILY     5.0       4                 3.6       100
# 10839  BOOKS_AND_REFERENCE     4.5     114  Varies with device      1000
# 10840            LIFESTYLE     4.5  398307                  19  10000000
#
#        Type Price Content Rating                     Genres      Last Updated  \
# ...

# %%
ap1["Last Updated"] = AP.to_datetime(ap1["Last Updated"])
ap1["Last Updated"] = (ap1["Last Updated"] - AP.to_datetime(ap1["Last Updated"]).min()).dt.days
ap1
# Out:
#                   Category  Rating Reviews                Size  Installs  \
# 0           ART_AND_DESIGN     4.1     159                  19     10000
# 1           ART_AND_DESIGN     3.9     967                  14    500000
# 2           ART_AND_DESIGN     4.7   87510                 8.7   5000000
# 3           ART_AND_DESIGN     4.5  215644                  25  50000000
# 4           ART_AND_DESIGN     4.3     967                 2.8    100000
# ...                    ...     ...     ...                 ...       ...
# 10834               FAMILY     4.0       7                 2.6       500
# 10836               FAMILY     4.5      38                  53      5000
# 10837               FAMILY     5.0       4                 3.6       100
# 10839  BOOKS_AND_REFERENCE     4.5     114  Varies with device      1000
# 10840            LIFESTYLE     4.5  398307                  19  10000000
#
#        Type Price Content Rating                     Genres  Last Updated  \
# ...

# %%
# Ratio
ap2 = ap1[ [ "Rating", "Reviews", "Size", "Installs", "Price" ] ]

# Categorical
cC = ["Category", "Genres", "Type", "Content Rating", "Current Ver"]
for i in cC:
 ap2 = AP.concat([ap2, AP.get_dummies(ap1[i])],axis=1)

# %%
ap1["Current Ver"].unique().tolist()
# Out:
# ['1.0.0',
#  '2.0.0',
#  '1.2.4',
#  'Varies with device',
#  '1.1',
#  '1.0',
#  '6.1.61.1',
#  '2.9.2',
#  '2.8',
#  '1.0.4',
#  '1.0.15',
#  '3.8',
#  '1.2.3',
#  '3.1',
#  '2.2.5',
#  '5.5.4',
#  '4.0',
#  '2.2.6.2',
#  '1.1.3',
#  '1.5',
#  '1.0.8',
#  '1.03',
#  '6.0',
#  '6.7.12.2018',
#  '1.2',
#  '2.20',
#  '1.1.0',
#  '1.6',
#  '2.1',
#  '1.0.9',
#  '1.3',
#  '1',
#  '2.0.1',
#  '1.46',
#  '1.6.1',
#  '11.0',
#  '3.0',
#  '1.7.1',
#  '2.5.1',
#  '1.0.1',
#  '2.493',
#  '1.9.1',
#  '1.7',
#  '2.20 Build 02',
#  '1.37',
#  '0.2.1',
#  '4.47.3',
#  '1.9.7',
#  '2.2.21',
#  '2.9',
#  '1.79',
#  '2.3.5.1',
#  '8.31',
#  '1.1.5.0',
#  '10.0.2',
#  '1.10.3',
#  '3.20.1',
#  '1.0.3',
#  '1.4',
#  '4.6.5',
#  '2.8.2',
#  '4.0.3',
#  '1.40',
#  '1.5.18',
#  '2.3.4',
#  '2.17',
#  '6.10.1',
#  '2.3.0',
#  '1.0.6',
#  '1.9',
#  '5.4',
#  '3.0.1',
#  '3.3.9',
#  '1.20',
#  '2.3.09',
#  '1.4.2',
#  '18.5',
#  '1.2.13',
#  '1.0.2.0',
#  '3.1.89',
#  '2.2.0',
#  '1.9.2',
#  '1.3.2',
# ...

# %%
# Ordinal
edu_map3 ={"Varies with device":0,
 "1.0 and up":1,
 "1.5 and up":2,
 "1.6 and up":3,
 "2.0 and up":4,
 "2.0.1 and up":5,
 "2.1 and up":6,
 "2.2 and up":7,
 "2.3 and up":8,
 "2.3.3 and up":9,
 "3.0 and up":10,
 "3.1 and up":11,
 "3.2 and up":12,
 "4.0 and up":13,
 "4.0.3 - 7.1.1":14,
 "4.0.3 and up":15,
 "4.1 - 7.1.1":16,
 "4.1 and up":17,
 "4.2 and up":18,
 "4.3 and up":19,
 "4.4 and up":20,
 "4.4W and up":21,
 "5.0 - 6.0":22,
 "5.0 - 8.0":23,
 "5.0 and up":24,
 "5.1 and up":25,
 "6.0 and up":26,
 "7.0 - 7.1.1":27,
 "7.0 and up":28,
 "7.1 and up":29,
 "8.0 and up":30
}
ap2['Android Ver'] = ap1['Android Ver'].map(edu_map3)
ap2['Last Updated'] = ap1['Last Updated']

# %%
ap2
# Out:
#        Rating Reviews                Size  Installs Price  ART_AND_DESIGN  \
# 0         4.1     159                  19     10000     0            True
# 1         3.9     967                  14    500000     0            True
# 2         4.7   87510                 8.7   5000000     0            True
# 3         4.5  215644                  25  50000000     0            True
# 4         4.3     967                 2.8    100000     0            True
# ...       ...     ...                 ...       ...   ...             ...
# 10834     4.0       7                 2.6       500     0           False
# 10836     4.5      38                  53      5000     0           False
# 10837     5.0       4                 3.6       100     0           False
# 10839     4.5     114  Varies with device      1000     0           False
# 10840     4.5  398307                  19  10000000     0           False
#
#        AUTO_AND_VEHICLES  BEAUTY  BOOKS_AND_REFERENCE  BUSINESS  ...  v6.7.14  \
# ...
