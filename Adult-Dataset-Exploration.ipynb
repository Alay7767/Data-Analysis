# %%
import pandas as pd
df = pd.read_csv("C:\\Assignments\\511\\adult.data", header = None)
df
# Out:
#        0                  1       2            3   4                    5   \
# 0      39          State-gov   77516    Bachelors  13        Never-married
# 1      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 2      38            Private  215646      HS-grad   9             Divorced
# 3      53            Private  234721         11th   7   Married-civ-spouse
# 4      28            Private  338409    Bachelors  13   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32556  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32557  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32558  58            Private  151910      HS-grad   9              Widowed
# 32559  22            Private  201490      HS-grad   9        Never-married
# 32560  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
# ...

# %%
df.iloc[250]
# Out:
# 0                      41
# 1                 Private
# 2                  112763
# 3             Prof-school
# 4                      15
# 5      Married-civ-spouse
# 6          Prof-specialty
# 7                    Wife
# 8                   White
# 9                  Female
# 10                      0
# 11                      0
# 12                     40
# 13          United-States
# 14                   >50K
# Name: 250, dtype: object

# %%
df[[0, 1, 3]]
# Out:
#         0                  1            3
# 0      39          State-gov    Bachelors
# 1      50   Self-emp-not-inc    Bachelors
# 2      38            Private      HS-grad
# 3      53            Private         11th
# 4      28            Private    Bachelors
# ...    ..                ...          ...
# 32556  27            Private   Assoc-acdm
# 32557  40            Private      HS-grad
# 32558  58            Private      HS-grad
# 32559  22            Private      HS-grad
# 32560  52       Self-emp-inc      HS-grad
#
# [32561 rows x 3 columns]

# %%
df[[0,1,5]].iloc[4]
# Out:
# 0                     28
# 1                Private
# 5     Married-civ-spouse
# Name: 4, dtype: object

# %%
df[ df[0]>=40]
# Out:
#        0                  1       2           3   4                       5   \
# 1      50   Self-emp-not-inc   83311   Bachelors  13      Married-civ-spouse
# 3      53            Private  234721        11th   7      Married-civ-spouse
# 6      49            Private  160187         9th   5   Married-spouse-absent
# 7      52   Self-emp-not-inc  209642     HS-grad   9      Married-civ-spouse
# 9      42            Private  159449   Bachelors  13      Married-civ-spouse
# ...    ..                ...     ...         ...  ..                     ...
# 32552  43            Private   84661   Assoc-voc  11      Married-civ-spouse
# 32554  53            Private  321865     Masters  14      Married-civ-spouse
# 32557  40            Private  154374     HS-grad   9      Married-civ-spouse
# 32558  58            Private  151910     HS-grad   9                 Widowed
# 32560  52       Self-emp-inc  287927     HS-grad   9      Married-civ-spouse
#
# ...

# %%
df [(df[0]>40) & (df[3] == " HS-grad")]
# Out:
#        0                  1       2         3   4                    5   \
# 7      52   Self-emp-not-inc  209642   HS-grad   9   Married-civ-spouse
# 21     54            Private  302146   HS-grad   9            Separated
# 24     59            Private  109015   HS-grad   9             Divorced
# 29     49            Private  193366   HS-grad   9   Married-civ-spouse
# 43     49            Private   94638   HS-grad   9            Separated
# ...    ..                ...     ...       ...  ..                  ...
# 32541  41                  ?  202822   HS-grad   9            Separated
# 32542  72                  ?  129912   HS-grad   9   Married-civ-spouse
# 32547  43            Private  260761   HS-grad   9   Married-civ-spouse
# 32558  58            Private  151910   HS-grad   9              Widowed
# 32560  52       Self-emp-inc  287927   HS-grad   9   Married-civ-spouse
#
#                        6               7       8        9      10  11  12  \
# ...

# %%
df [(df[0]>40) & (df[3].isin([" HS-grad", " 11th"," 10th"," 9th"]))]
# Out:
#        0                  1       2         3   4                       5   \
# 3      53            Private  234721      11th   7      Married-civ-spouse
# 6      49            Private  160187       9th   5   Married-spouse-absent
# 7      52   Self-emp-not-inc  209642   HS-grad   9      Married-civ-spouse
# 21     54            Private  302146   HS-grad   9               Separated
# 23     43            Private  117037      11th   7      Married-civ-spouse
# ...    ..                ...     ...       ...  ..                     ...
# 32541  41                  ?  202822   HS-grad   9               Separated
# 32542  72                  ?  129912   HS-grad   9      Married-civ-spouse
# 32547  43            Private  260761   HS-grad   9      Married-civ-spouse
# 32558  58            Private  151910   HS-grad   9                 Widowed
# 32560  52       Self-emp-inc  287927   HS-grad   9      Married-civ-spouse
#
# ...

# %%
df[1].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
df[1].value_counts()
# Out:
# 1
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
df[0].value_counts()
# Out:
# 0
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: count, Length: 73, dtype: int64

# %%
df[[1, 3, 5, 7, 9, 10]]
# Out:
#                       1            3                    5               7   \
# 0              State-gov    Bachelors        Never-married   Not-in-family
# 1       Self-emp-not-inc    Bachelors   Married-civ-spouse         Husband
# 2                Private      HS-grad             Divorced   Not-in-family
# 3                Private         11th   Married-civ-spouse         Husband
# 4                Private    Bachelors   Married-civ-spouse            Wife
# ...                  ...          ...                  ...             ...
# 32556            Private   Assoc-acdm   Married-civ-spouse            Wife
# 32557            Private      HS-grad   Married-civ-spouse         Husband
# 32558            Private      HS-grad              Widowed       Unmarried
# 32559            Private      HS-grad        Never-married       Own-child
# 32560       Self-emp-inc      HS-grad   Married-civ-spouse            Wife
#
#             9      10
# 0         Male   2174
# ...

# %%
df_male = df[(df[3] == " Masters") & (df[9] == " Male")][0].count()

# %%
for column in df.select_dtypes(exclude=['number']).columns:
    unique_values_count = df[column].nunique()
    print(f"Column '{column}' has {unique_values_count} unique values.")
# Out:
# Column '1' has 9 unique values.
# Column '3' has 16 unique values.
# Column '5' has 7 unique values.
# Column '6' has 15 unique values.
# Column '7' has 6 unique values.
# Column '8' has 5 unique values.
# Column '9' has 2 unique values.
# Column '13' has 42 unique values.
# Column '14' has 2 unique values.

# %%
df_female = df[(df[3] == " Masters") & (df[9] == " Female")][0].count()

# %%
total = df_male + df_female

# %%
print(f"Percentage of males is {df_male/total*100}% and Percentage of females is {df_female/total*100}%")
# Out:
# Percentage of males is 68.89146836912361% and Percentage of females is 31.108531630876378%

# %%
df1 = pd.read_csv("C:\\Assignments\\511\\googleplaystore.csv")
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df1["Category"].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df1["Category"].value_counts()
# Out:
# Category
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %%
df1["App"].value_counts()
# Out:
# App
# ROBLOX                                                9
# CBS Sports App - Scores, News, Stats & Watch Live     8
# ESPN                                                  7
# Duolingo: Learn Languages Free                        7
# Candy Crush Saga                                      7
#                                                      ..
# Meet U - Get Friends for Snapchat, Kik & Instagram    1
# U-Report                                              1
# U of I Community Credit Union                         1
# Waiting For U Launcher Theme                          1
# iHoroscope - 2018 Daily Horoscope & Astrology         1
# Name: count, Length: 9660, dtype: int64
